# %% [markdown]
# GP Regression with GPflow
# --
#
# *James Hensman, 2015, 2016*
#
# GP regression (with Gaussian noise) is the most straightforward GP model in GPflow. Because of the conjugacy of the latent process and the noise, the marginal likelihood $p(\mathbf y\,|\,\theta)$ can be computed exactly.
#
# This notebook shows how to build a GPR model, estimate the parameters $\theta$ by both maximum likelihood and MCMC.

# %% [markdown]
# ## Editted by @fujiisoup
#
# In this note, I demonstrate the updated implementation where the model can be reused with different data.
# Please see
#
# `m.X = X_new
# m.Y = Y_new`

# %%
from __future__ import print_function
import gpflow
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import time

# %%
# build a very simple data set:
N = 12
X = np.random.rand(N,1)
Y = np.sin(12*X) + 0.66*np.cos(25*X) + np.random.randn(N,1)*0.1 + 3
plt.figure()
plt.plot(X, Y, 'kx', mew=2)

# %% [markdown]
# Maximum Likelihood estimation
# --

# %%
#build the GPR object
k = gpflow.kernels.Matern52(1)
meanf = gpflow.mean_functions.Linear(1,0)
m = gpflow.gpr.GPR(X, Y, k, meanf)
m.likelihood.variance = 0.01

# %%
print("Here are the parameters before optimization")
m
# Out:
# Here are the parameters before optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.01]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 0.]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[ 1.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr></table>

# %%
t = time.time()
m.optimize()
print("Here are the parameters after optimization")
print(time.time() - t, " (s) for compilation and optimization")
m
# Out:
# Here are the parameters after optimization
# 1.0021443367004395  (s) for compilation and optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.33170899]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 2.93178967]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[ 1.03591868]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 11.47485011]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[  1.01013448e-06]</td><td>None</td><td>+ve</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbcf0ef8080>,
#  <matplotlib.lines.Line2D at 0x7fbcf0efe2b0>]

# %% [markdown]
# ### For another data

# %%
N = 12
X = np.random.rand(N,1)
Y = np.sin(12*X) + 0.66*np.cos(25*X) + np.random.randn(N,1)*0.1 + 3
# update data
m.X = X
m.Y = Y

# %%
t = time.time()
m.optimize()
print("Here are the parameters after optimization")
print(time.time() - t, " (s) for optimization")
m
# Out:
# Here are the parameters after optimization
# 0.01171422004699707  (s) for optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.57853565]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 3.30542603]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[-0.39921897]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 11.47485011]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[  1.01013447e-06]</td><td>None</td><td>+ve</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbcf0e7f780>,
#  <matplotlib.lines.Line2D at 0x7fbcf0e839b0>]

# %% [markdown]
# ### For another data with different shape

# %%
# shape changed!
N = 13
X = np.random.rand(N,1)
Y = np.sin(12*X) + 0.66*np.cos(25*X) + np.random.randn(N,1)*0.1 + 3
# update data
m.X = X
m.Y = Y

# %%
t = time.time()
m.optimize()
print("Here are the parameters after optimization")
print(time.time() - t, " (s) for optimization")
m
# Out:
# Here are the parameters after optimization
# 0.01124715805053711  (s) for optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.64324075]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 3.01744166]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[-0.60064261]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 11.47485011]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[  1.01013447e-06]</td><td>None</td><td>+ve</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbcf0e73f60>,
#  <matplotlib.lines.Line2D at 0x7fbccf9c41d0>]

# %% [markdown]
# ## Fixing the parameters

# %%
# Fix the lengthscale
m.kern.lengthscales.fixed = True
m.kern.lengthscales = 0.2

# %%
t = time.time()
m.optimize()
print("Here are the parameters after optimization")
print(time.time() - t, " (s) for compilation and optimization")
m
# Out:
# Here are the parameters after optimization
# 0.7565584182739258  (s) for compilation and optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.64324064]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 3.01744319]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[-0.60064094]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 0.2]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.variance</td><td>[  1.01013447e-06]</td><td>None</td><td>+ve</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbd30798438>,
#  <matplotlib.lines.Line2D at 0x7fbd3078d668>]

# %% [markdown]
# ### With different value for fixed param

# %%
# Change the lengthscale
m.kern.lengthscales = 0.1

# %%
t = time.time()
m.optimize()
print("Here are the parameters after optimization")
print(time.time() - t, " (s) for optimization")
m
# Out:
# Here are the parameters after optimization
# 0.005910158157348633  (s) for optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.64323822]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 3.01743914]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[-0.60063605]]</td><td>None</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 0.1]</td><td>None</td><td>[FIXED]</td></tr><tr><td>model.kern.variance</td><td>[  1.01013447e-06]</td><td>None</td><td>+ve</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbd3812f9e8>,
#  <matplotlib.lines.Line2D at 0x7fbd38133c18>]

# %% [markdown]
# MCMC
# --
# First, we'll set come priors on the kernel parameters, then we'll run mcmc and see how much posterior uncertainty there is in the parameters.

# %%
m.kern.lengthscales.fixed = False

# %%
#we'll choose rather arbitrary priors. 
m.kern.lengthscales.prior = gpflow.priors.Gamma(1., 1.)
m.kern.variance.prior = gpflow.priors.Gamma(1., 1.)
m.likelihood.variance.prior = gpflow.priors.Gamma(1., 1.)
m.mean_function.A.prior = gpflow.priors.Gaussian(0., 10.)
m.mean_function.b.prior = gpflow.priors.Gaussian(0., 10.)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.64323822]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>model.mean_function.b</td><td>[ 3.01743914]</td><td>N([ 0.],[ 10.])</td><td>(none)</td></tr><tr><td>model.mean_function.A</td><td>[[-0.60063605]]</td><td>N([ 0.],[ 10.])</td><td>(none)</td></tr><tr><td>model.kern.lengthscales</td><td>[ 0.1]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[  1.01013447e-06]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr></table>

# %%
samples = m.sample(500, epsilon = 0.1, verbose=1)
# Out:
# Iteration:  100 	 Acc Rate:  97.0 %
# Iteration:  200 	 Acc Rate:  97.0 %
# Iteration:  300 	 Acc Rate:  100.0 %
# Iteration:  400 	 Acc Rate:  98.0 %
# Iteration:  500 	 Acc Rate:  100.0 %

# %%
plt.figure()
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbccf53c438>,
#  <matplotlib.lines.Line2D at 0x7fbccf53c6d8>,
#  <matplotlib.lines.Line2D at 0x7fbccf53c8d0>,
#  <matplotlib.lines.Line2D at 0x7fbccf53cac8>,
#  <matplotlib.lines.Line2D at 0x7fbccf53ccc0>]

# %%
#Note. All these labels are wrong (or, most probably wrong). We need some machinery for labelling posterior samples!

f, axs = plt.subplots(1,3, figsize=(12,4), tight_layout=True)
axs[0].plot(samples[:,0], samples[:,1], 'k.', alpha = 0.15)
axs[0].set_xlabel('noise_variance')
axs[0].set_ylabel('signal_variance')
axs[1].plot(samples[:,0], samples[:,2], 'k.', alpha = 0.15)
axs[1].set_xlabel('noise_variance')
axs[1].set_ylabel('lengthscale')
axs[2].plot(samples[:,2], samples[:,1], 'k.', alpha = 0.1)
axs[2].set_xlabel('lengthscale')
axs[2].set_ylabel('signal_variance')
# Out:
# /home/mqbssaby/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py:1742: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#an attempt to plot the function posterior
#Note that we should really sample the function values here, instead of just using the mean. 
#We are under-representing the uncertainty here. 
# TODO: get full_covariance of the predictions (predict_f only?)

plt.figure()

for s in samples:
    m.set_state(s)
    mean, _ = m.predict_y(xx)
    plt.plot(xx, mean, 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)

# %% [markdown]
# ## Variational inference

# %%
N = 25
X = np.arange(N, dtype=np.float64).reshape(-1,1)
Y = np.random.poisson(np.exp(np.sin(12*X) + 0.66*np.cos(25*X)))*1.0

# %%
#build the GP object
k = gpflow.kernels.RBF(1)
lik = gpflow.likelihoods.Poisson()
m = gpflow.vgp.VGP(X, Y, k, likelihood=lik)

# %%
t = time.time()
m.optimize()
print(time.time() - t, " (s) for compilation and optimization")
# Out:
# 1.4281647205352783  (s) for compilation and optimization

# %%
#plot!
xx = np.linspace(-1., N+1., 100)[:,None]
mean, var = m.predict_f(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, np.exp(mean), 'b', lw=2)
plt.plot(xx, np.exp(mean + 2*np.sqrt(var)), 'b--', xx, np.exp(mean - 2*np.sqrt(var)), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbcce6145f8>,
#  <matplotlib.lines.Line2D at 0x7fbcce619828>]

# %% [markdown]
# ### For another data with the same shape

# %%
Y = 30.*np.exp(-((X-np.ones((N,1))*5.)*0.1)**2.) + np.random.rand(N,1)*3.
m.Y = Y

# %%
t = time.time()
m.optimize()
print(time.time() - t, " (s) for optimization")
# Out:
# 0.28702282905578613  (s) for optimization

# %%
#plot!
xx = np.linspace(-1., N+1., 100)[:,None]
mean, var = m.predict_f(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, np.exp(mean), 'b', lw=2)
plt.plot(xx, np.exp(mean + 2*np.sqrt(var)), 'b--', xx, np.exp(mean - 2*np.sqrt(var)), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbcce5cc9e8>,
#  <matplotlib.lines.Line2D at 0x7fbcce5d3c18>]

# %% [markdown]
# ### For another data with different shape

# %%
# shape changed
N = 34
X = np.arange(N, dtype=np.float64).reshape(-1,1)
Y = 14.*np.exp(-((X-np.ones((N,1))*5.)*0.1)**2.) + np.random.rand(N,1)*3.
m.X = X
m.Y = Y

# %%
t = time.time()
m.optimize()
print(time.time() - t, " (s) for compilation and optimization")
# Out:
# 1.4511466026306152  (s) for compilation and optimization

# %%
#plot!
xx = np.linspace(-1., N+1., 100)[:,None]
mean, var = m.predict_f(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, np.exp(mean), 'b', lw=2)
plt.plot(xx, np.exp(mean + 2*np.sqrt(var)), 'b--', xx, np.exp(mean - 2*np.sqrt(var)), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7fbccea319b0>,
#  <matplotlib.lines.Line2D at 0x7fbccea2abe0>]
