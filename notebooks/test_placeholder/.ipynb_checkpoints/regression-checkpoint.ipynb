# %% [markdown]
# GP Regression with GPflow
# --
#
# *James Hensman, 2015, 2016*
#
# GP regression (with Gaussian noise) is the most straightforward GP model in GPflow. Because of the conjugacy of the latent process and the noise, the marginal likelihood $p(\mathbf y\,|\,\theta)$ can be computed exactly.
#
# This notebook shows how to build a GPR model, estimate the parameters $\theta$ by both maximum likelihood and MCMC.

# %%
import sys

# %%
sys.path.append('../../')

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# /home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
import GPflow
print GPflow.__file__
# Out:
# ../../GPflow/__init__.pyc

# %%
reload(GPflow)
# Out:
# <module 'GPflow' from '../../GPflow/__init__.pyc'>

# %%
# build a very simple data set:
np.random.seed(1)
N = 12
X = np.random.rand(N,1)
Y = np.sin(12*X) + 0.66*np.cos(25*X) + np.random.randn(N,1)*0.1 + 3
plt.figure()
plt.plot(X, Y, 'kx', mew=2)

# %% [markdown]
# Maximum Likelihood estimation
# --

# %%
#build the GPR object
k = GPflow.kernels.Matern52(1)
meanf = GPflow.mean_functions.Linear(1,0)
m = GPflow.gpr.GPR(X, Y, k, meanf)
m.likelihood.variance = 0.01

# %%
print "Here are the parameters before optimization"
m
# Out:
# Here are the parameters before optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.01]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.lengthscales</td><td>[ 1.]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.A</td><td>[[ 1.]]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.b</td><td>[ 0.]</td><td>None</td><td>(none)</td></tr></table>

# %%
m._compile()
# Out:
# compiling tensorflow function...
# done

# %%
m.optimize()
print "Here are the parameters after optimization"
m
# Out:
# optimization terminated, setting model state
# Here are the parameters after optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.00037948]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[ 0.79209109]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.lengthscales</td><td>[ 0.10131151]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.A</td><td>[[ 0.37110123]]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.b</td><td>[ 3.25050611]</td><td>None</td><td>(none)</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f1974133ad0>,
#  <matplotlib.lines.Line2D at 0x7f19740c6cd0>]

# %%
m.get_data()[m.Y] = Y*2.0

# %%
m.optimize()
print "Here are the parameters after optimization"
m
# Out:
# optimization terminated, setting model state
# Here are the parameters after optimization
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.00151796]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[ 3.16834904]</td><td>None</td><td>+ve</td></tr><tr><td>model.kern.lengthscales</td><td>[ 0.10131126]</td><td>None</td><td>+ve</td></tr><tr><td>model.mean_function.A</td><td>[[ 0.74221975]]</td><td>None</td><td>(none)</td></tr><tr><td>model.mean_function.b</td><td>[ 6.5010194]</td><td>None</td><td>(none)</td></tr></table>

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f197b9ec190>,
#  <matplotlib.lines.Line2D at 0x7f196c7bf2d0>]

# %%
m.likelihood.variance = 0.02
m._compile()
# Out:
# compiling tensorflow function...
# done

# %%
#plot!
xx = np.linspace(-0.1, 1.1, 100)[:,None]
mean, var = m.predict_y(xx)
plt.figure()
plt.plot(X, Y, 'kx', mew=2)
plt.plot(xx, mean, 'b', lw=2)
plt.plot(xx, mean + 2*np.sqrt(var), 'b--', xx, mean - 2*np.sqrt(var), 'b--', lw=1.2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f196c1b6c50>,
#  <matplotlib.lines.Line2D at 0x7f195c64f0d0>]

# %%
import tensorflow as tf

# %%
m.optimize(tf.train.GradientDescentOptimizer(learning_rate=0.001), max_iters=10)
print "Here are the parameters after optimization"
m
# Out:
# compiling tensorflow function...
# done
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-23-f5aa008c922c> in <module>()
# ----> 1 m.optimize(tf.train.GradientDescentOptimizer(learning_rate=0.001), max_iters=10)
#       2 print "Here are the parameters after optimization"
#       3 m
#
# /mnt/LAUE_RAID/btsync/working_dir/projects/calibration_bayes/blind_noise_modeling/GPflow.git/GPflow/model.pyc in optimize(self, method, tol, callback, max_iters, calc_feed_dict, **kw)
#     205         else:
#     206             return self._optimize_tf(method, callback, max_iters,
# --> 207                                      calc_feed_dict, **kw)
#     208
#     209     def _optimize_tf(self, method, callback, max_iters, calc_feed_dict):
#
# /mnt/LAUE_RAID/btsync/working_dir/projects/calibration_bayes/blind_noise_modeling/GPflow.git/GPflow/model.pyc in _optimize_tf(self, method, callback, max_iters, calc_feed_dict)
#     220                 else:
#     221                     feed_dict = self.get_data().update(calc_feed_dict())
# --> 222                 self._session.run(opt_step, feed_dict=feed_dict)
#     223                 if callback is not None:
#     224                     callback(self._session.run(self._free_vars))
#
# /home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     370     try:
#     371       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 372                          run_metadata_ptr)
#     373       if run_metadata:
#     374         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     634     try:
#     635       results = self._do_run(handle, target_list, unique_fetches,
# --> 636                              feed_dict_string, options, run_metadata)
#     637     finally:
#     638       # The movers are no longer used. Delete them.
#
# /home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     706     if handle is None:
#     707       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 708                            target_list, options, run_metadata)
#     709     else:
#     710       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     726         except KeyError:
#     727           pass
# --> 728       raise type(e)(node_def, op, message)
#     729
#     730   def _extend_graph(self):
#
# InvalidArgumentError: You must feed a value for placeholder tensor 'X' with dtype double and shape [12,1]
# 	 [[Node: X = Placeholder[dtype=DT_DOUBLE, shape=[12,1], _device="/job:localhost/replica:0/task:0/cpu:0"]()]]
# Caused by op u'X', defined at:
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/runpy.py", line 162, in _run_module_as_main
#     "__main__", fname, loader, pkg_name)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/runpy.py", line 72, in _run_code
#     exec code in run_globals
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/ipykernel/__main__.py", line 3, in <module>
#     app.launch_new_instance()
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/traitlets/config/application.py", line 596, in launch_instance
#     app.start()
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/ipykernel/kernelapp.py", line 442, in start
#     ioloop.IOLoop.instance().start()
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/zmq/eventloop/ioloop.py", line 162, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tornado/ioloop.py", line 883, in start
#     handler_func(fd_obj, events)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tornado/stack_context.py", line 275, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 276, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 228, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/ipykernel/kernelbase.py", line 391, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/ipykernel/ipkernel.py", line 199, in do_execute
#     shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2723, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2825, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/IPython/core/interactiveshell.py", line 2885, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-7-6db8092258e2>", line 4, in <module>
#     m = GPflow.gpr.GPR(X, Y, k, meanf)
#   File "../../GPflow/gpr.py", line 20, in __init__
#     GPModel.__init__(self, X, Y, kern, likelihood, mean_function)
#   File "../../GPflow/model.py", line 328, in __init__
#     self.X = tf.placeholder(tf.float64, shape=X.shape, name="X")
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/ops/array_ops.py", line 895, in placeholder
#     name=name)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/ops/gen_array_ops.py", line 1238, in _placeholder
#     name=name)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/ops/op_def_library.py", line 704, in apply_op
#     op_def=op_def)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 2260, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/tensorflow/python/framework/ops.py", line 1230, in __init__
#     self._traceback = _extract_stack()

# %% [markdown]
# MCMC
# --
# First, we'll set come priors on the kernel parameters, then we'll run mcmc and see how much posterior uncertainty there is in the parameters.

# %%
#we'll choose rather arbitrary priors. 
m.kern.lengthscales.prior = GPflow.priors.Gamma(1., 1.)
m.kern.variance.prior = GPflow.priors.Gamma(1., 1.)
m.likelihood.variance.prior = GPflow.priors.Gamma(1., 1.)
m.mean_function.A.prior = GPflow.priors.Gaussian(0., 10.)
m.mean_function.b.prior = GPflow.priors.Gaussian(0., 10.)
m
# Out:
# <table id='params' width=100%><tr><td>Name</td><td>values</td><td>prior</td><td>constraint</td></tr><tr><td>model.likelihood.variance</td><td>[ 0.02]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>model.kern.variance</td><td>[ 3.16834904]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>model.kern.lengthscales</td><td>[ 0.10131126]</td><td>Ga([ 1.],[ 1.])</td><td>+ve</td></tr><tr><td>model.mean_function.A</td><td>[[ 0.74221975]]</td><td>N([ 0.],[ 10.])</td><td>(none)</td></tr><tr><td>model.mean_function.b</td><td>[ 6.5010194]</td><td>N([ 0.],[ 10.])</td><td>(none)</td></tr></table>

# %%
samples = m.sample(500, epsilon = 0.1, verbose=1)
# Out:
# compiling tensorflow function...
# done
# ../../GPflow/hmc.py:97: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   samples[t/thin] = x
# ../../GPflow/hmc.py:101: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   samples[t/thin] = x_old
# Iteration:  100 	 Acc Rate:  97.0 %
# Iteration:  200 	 Acc Rate:  99.0 %
# Iteration:  300 	 Acc Rate:  100.0 %
# Iteration:  400 	 Acc Rate:  99.0 %
# Iteration:  500 	 Acc Rate:  99.0 %

# %%
plt.figure()
plt.plot(samples)
# Out:
# [<matplotlib.lines.Line2D at 0x7f190f526f10>,
#  <matplotlib.lines.Line2D at 0x7f190f533150>,
#  <matplotlib.lines.Line2D at 0x7f190f533290>,
#  <matplotlib.lines.Line2D at 0x7f190f5333d0>,
#  <matplotlib.lines.Line2D at 0x7f190f533510>]

# %%
#Note. All these labels are wrong (or, most probably wrong). We need some machinery for labelling posterior samples!

f, axs = plt.subplots(1,3, figsize=(12,4), tight_layout=True)
axs[0].plot(samples[:,0], samples[:,1], 'k.', alpha = 0.15)
axs[0].set_xlabel('noise_variance')
axs[0].set_ylabel('signal_variance')
axs[1].plot(samples[:,0], samples[:,2], 'k.', alpha = 0.15)
axs[1].set_xlabel('noise_variance')
axs[1].set_ylabel('lengthscale')
axs[2].plot(samples[:,2], samples[:,1], 'k.', alpha = 0.1)
axs[2].set_xlabel('lengthscale')
axs[2].set_ylabel('signal_variance')
# Out:
# /home/keisukefujii/anaconda2/envs/GPflow/lib/python2.7/site-packages/matplotlib/figure.py:1744: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %%
#an attempt to plot the function posterior
#Note that we should really sample the function values here, instead of just using the mean. 
#We are under-representing the uncertainty here. 
# TODO: get full_covariance of the predictions (predict_f only?)

plt.figure()

for s in samples:
    m.set_state(s)
    mean, _ = m.predict_y(xx)
    plt.plot(xx, mean, 'b', lw=2, alpha = 0.05)
    
plt.plot(X, Y, 'kx', mew=2)
